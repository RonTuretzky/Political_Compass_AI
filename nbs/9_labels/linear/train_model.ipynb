# %%
#| default_exp run
#|  export

def yield_tokens(
        data_iter # Iterable database instance
):
    tokenizer = get_tokenizer('basic_english')
    for _, text in data_iter:
        yield tokenizer(text)

def split_string(string):
    parts = string[1:-1].split(",")
    parts = [part.strip().strip("'") for part in parts]
    return parts[0], parts[1]

def return_iters(_db:str # Path to db
                 ):
    train_iter = []
    test_iter = []
    file = open(_db, 'r', encoding='latin1')
    mapping = {
        "Libertarian Left": 1,
        "Libertarian Right": 2,
        "Authoritarian Left": 3,
        "Authoritarian Right": 4,
        "Centrist": 5,
        "Authoritarian Center": 6,
        "Left": 7,
        "Right": 8,
        "Libertarian Center": 9,
    }
    lines = file.readlines()
    for line in lines:
        opinion,text = split_string(line)
        train_iter+=[(mapping[opinion],text)]
        test_iter+=[(mapping[opinion],text)]
    train_iter = iter(train_iter)
    test_iter = iter(test_iter)
    file.close()
    return train_iter, test_iter

# %%
#|  export
from torchtext.data.utils import get_tokenizer
from Political_Compass_AI.model import TextClassificationModel
from Political_Compass_AI.training import train
from Political_Compass_AI.training import evaluate
from torchtext.data.functional import to_map_style_dataset
from torchtext.vocab import build_vocab_from_iterator
from torch.utils.data import DataLoader
from torch.utils.data.dataset import random_split
import time
import torch
import torch.optim as optim
import torch.utils.data
import pandas as pd

def collate_batch(
        batch
):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    label_pipeline = lambda x: int(x) - 1
    label_list, text_list, offsets = [], [], [0]
    for (_label, _text) in batch:
        label_list.append(label_pipeline(_label))
        processed_text = torch.tensor(text_pipeline(_text), dtype=torch.int64)
        text_list.append(processed_text)
        offsets.append(processed_text.size(0))
    label_list = torch.tensor(label_list, dtype=torch.int64)
    offsets = torch.tensor(offsets[:-1]).cumsum(dim=0)
    text_list = torch.cat(text_list)
    return label_list.to(device), text_list.to(device), offsets.to(device)

def train_model(
    db,
    batch_size,
    emsize,
    lr,
    optimizer_name,
    epochs
):
    global text_pipeline
    tokenizer = get_tokenizer('basic_english')
    text_pipeline = lambda x: vocab(tokenizer(x))
    label_pipeline = lambda x: int(x) - 1
    train_iter, test_iter = return_iters(db)
    vocab = build_vocab_from_iterator(yield_tokens(train_iter), specials=["<unk>"])
    vocab.set_default_index(vocab["<unk>"])
    train_iter, test_iter = return_iters(db)
    dataloader = DataLoader(train_iter, batch_size=batch_size, shuffle=False, collate_fn=collate_batch)
    train_iter, test_iter = return_iters(db)
    num_class = len(set([label for (label, text) in train_iter]))
    vocab_size = len(vocab)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = TextClassificationModel(vocab_size, emsize, num_class).to(device)
    criterion = torch.nn.CrossEntropyLoss()
    optimizer = getattr(optim, optimizer_name)(model.parameters(), lr=lr)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, 1, gamma=0.1)
    _optim = optimizer_name
    total_accu = None
    train_iter, test_iter = return_iters(db)
    train_dataset = to_map_style_dataset(train_iter)
    test_dataset = to_map_style_dataset(test_iter)
    num_train = int(len(train_dataset) * 0.95)
    split_train_, split_valid_ = \
        random_split(train_dataset, [num_train, len(train_dataset) - num_train])

    train_dataloader = DataLoader(split_train_, batch_size=batch_size,
                                  shuffle=True, collate_fn=collate_batch)
    valid_dataloader = DataLoader(split_valid_, batch_size=batch_size,
                                  shuffle=True, collate_fn=collate_batch)
    test_dataloader = DataLoader(test_dataset, batch_size=batch_size,
                                 shuffle=True, collate_fn=collate_batch)
    for epoch in range(1, epochs + 1):
        epoch_start_time = time.time()
        train(train_dataloader, model, optimizer, epoch)
        accu_val = evaluate(valid_dataloader, model)
        if total_accu is not None and total_accu > accu_val:
            scheduler.step()
        else:
            total_accu = accu_val
        print('-' * 59)
        print('| end of epoch {:3d} | time: {:5.2f}s | '
              'valid accuracy {:8.3f} '.format(epoch,
                                               time.time() - epoch_start_time,
                                               accu_val))
        print('-' * 59)
    df_Log = {"Database_file":[],"Epochs":[],"LR":[],"Batch_Size":[],
              "Final_accu":[],"Optimzer":[],"Test Accuracy":[],"Embed Size":[],"Vocabulary Size":[]}
    accu_test = evaluate(test_dataloader,model)
    out = 'test accuracy {:8.3f}'.format(accu_test)
    df_Log["Database_file"].append(db)
    df_Log["Epochs"].append(str(epochs))
    df_Log["LR"].append(str(lr))
    df_Log["Batch_Size"].append(str(batch_size))
    df_Log["Final_accu"].append(str(accu_val))
    df_Log["Optimzer"].append(optimizer_name)
    df_Log["Test Accuracy"].append(accu_test)
    df_Log["Embed Size"].append(emsize)
    df_Log["Vocabulary Size"].append(vocab_size)
    dataframe = pd.DataFrame(df_Log)
    dataframe.to_csv('Run_Ledger.csv',mode='a', index=False,sep="\t")
    return model

# %%
args ={
    "db":"../../../data/9_labels/linear/full",
    "batch_size":32,
    "emsize":64,
    "lr":5,
    "optimizer_name":"Adagrad",
    "epochs":20
}
trained_model = train_model(**args)
torch.save(trained_model.state_dict(),"model.pth")
# Out:
# | epoch   1 |    50/ 5775 batches | accuracy    0.125
# | epoch   1 |   100/ 5775 batches | accuracy    0.132
# | epoch   1 |   150/ 5775 batches | accuracy    0.126
# | epoch   1 |   200/ 5775 batches | accuracy    0.133
# | epoch   1 |   250/ 5775 batches | accuracy    0.151
# | epoch   1 |   300/ 5775 batches | accuracy    0.131
# | epoch   1 |   350/ 5775 batches | accuracy    0.134
# | epoch   1 |   400/ 5775 batches | accuracy    0.132
# | epoch   1 |   450/ 5775 batches | accuracy    0.131
# | epoch   1 |   500/ 5775 batches | accuracy    0.129
# | epoch   1 |   550/ 5775 batches | accuracy    0.129
# | epoch   1 |   600/ 5775 batches | accuracy    0.118
# | epoch   1 |   650/ 5775 batches | accuracy    0.134
# | epoch   1 |   700/ 5775 batches | accuracy    0.127
# | epoch   1 |   750/ 5775 batches | accuracy    0.161
# | epoch   1 |   800/ 5775 batches | accuracy    0.141
# | epoch   1 |   850/ 5775 batches | accuracy    0.123
# | epoch   1 |   900/ 5775 batches | accuracy    0.133
# | epoch   1 |   950/ 5775 batches | accuracy    0.129
# | epoch   1 |  1000/ 5775 batches | accuracy    0.147
# | epoch   1 |  1050/ 5775 batches | accuracy    0.137
# | epoch   1 |  1100/ 5775 batches | accuracy    0.133
# | epoch   1 |  1150/ 5775 batches | accuracy    0.142
# | epoch   1 |  1200/ 5775 batches | accuracy    0.142
# | epoch   1 |  1250/ 5775 batches | accuracy    0.147
# | epoch   1 |  1300/ 5775 batches | accuracy    0.138
# | epoch   1 |  1350/ 5775 batches | accuracy    0.138
# | epoch   1 |  1400/ 5775 batches | accuracy    0.133
# | epoch   1 |  1450/ 5775 batches | accuracy    0.135
# | epoch   1 |  1500/ 5775 batches | accuracy    0.149
# | epoch   1 |  1550/ 5775 batches | accuracy    0.132
# | epoch   1 |  1600/ 5775 batches | accuracy    0.145
# | epoch   1 |  1650/ 5775 batches | accuracy    0.134
# | epoch   1 |  1700/ 5775 batches | accuracy    0.145
# | epoch   1 |  1750/ 5775 batches | accuracy    0.133
# | epoch   1 |  1800/ 5775 batches | accuracy    0.152
# | epoch   1 |  1850/ 5775 batches | accuracy    0.146
# | epoch   1 |  1900/ 5775 batches | accuracy    0.144
# | epoch   1 |  1950/ 5775 batches | accuracy    0.129
# | epoch   1 |  2000/ 5775 batches | accuracy    0.139
# | epoch   1 |  2050/ 5775 batches | accuracy    0.144
# | epoch   1 |  2100/ 5775 batches | accuracy    0.133
# | epoch   1 |  2150/ 5775 batches | accuracy    0.144
# | epoch   1 |  2200/ 5775 batches | accuracy    0.155
# | epoch   1 |  2250/ 5775 batches | accuracy    0.139
# | epoch   1 |  2300/ 5775 batches | accuracy    0.116
# | epoch   1 |  2350/ 5775 batches | accuracy    0.139
# | epoch   1 |  2400/ 5775 batches | accuracy    0.129
# | epoch   1 |  2450/ 5775 batches | accuracy    0.144
# | epoch   1 |  2500/ 5775 batches | accuracy    0.150
# | epoch   1 |  2550/ 5775 batches | accuracy    0.142
# | epoch   1 |  2600/ 5775 batches | accuracy    0.145
# | epoch   1 |  2650/ 5775 batches | accuracy    0.132
# | epoch   1 |  2700/ 5775 batches | accuracy    0.149
# | epoch   1 |  2750/ 5775 batches | accuracy    0.151
# | epoch   1 |  2800/ 5775 batches | accuracy    0.138
# | epoch   1 |  2850/ 5775 batches | accuracy    0.141
# | epoch   1 |  2900/ 5775 batches | accuracy    0.147
# | epoch   1 |  2950/ 5775 batches | accuracy    0.138
# | epoch   1 |  3000/ 5775 batches | accuracy    0.153
# | epoch   1 |  3050/ 5775 batches | accuracy    0.147
# | epoch   1 |  3100/ 5775 batches | accuracy    0.144
# | epoch   1 |  3150/ 5775 batches | accuracy    0.141
# | epoch   1 |  3200/ 5775 batches | accuracy    0.113
# | epoch   1 |  3250/ 5775 batches | accuracy    0.142
# | epoch   1 |  3300/ 5775 batches | accuracy    0.141
# | epoch   1 |  3350/ 5775 batches | accuracy    0.137
# | epoch   1 |  3400/ 5775 batches | accuracy    0.150
# | epoch   1 |  3450/ 5775 batches | accuracy    0.135
# | epoch   1 |  3500/ 5775 batches | accuracy    0.136
# | epoch   1 |  3550/ 5775 batches | accuracy    0.139
# | epoch   1 |  3600/ 5775 batches | accuracy    0.142
# | epoch   1 |  3650/ 5775 batches | accuracy    0.138
# | epoch   1 |  3700/ 5775 batches | accuracy    0.136
# | epoch   1 |  3750/ 5775 batches | accuracy    0.140
# | epoch   1 |  3800/ 5775 batches | accuracy    0.142
# | epoch   1 |  3850/ 5775 batches | accuracy    0.128
# | epoch   1 |  3900/ 5775 batches | accuracy    0.133
# | epoch   1 |  3950/ 5775 batches | accuracy    0.131
# | epoch   1 |  4000/ 5775 batches | accuracy    0.160
# | epoch   1 |  4050/ 5775 batches | accuracy    0.143
# | epoch   1 |  4100/ 5775 batches | accuracy    0.151
# | epoch   1 |  4150/ 5775 batches | accuracy    0.158
# | epoch   1 |  4200/ 5775 batches | accuracy    0.161
# | epoch   1 |  4250/ 5775 batches | accuracy    0.148
# | epoch   1 |  4300/ 5775 batches | accuracy    0.156
# | epoch   1 |  4350/ 5775 batches | accuracy    0.142
# | epoch   1 |  4400/ 5775 batches | accuracy    0.141
# | epoch   1 |  4450/ 5775 batches | accuracy    0.142
# | epoch   1 |  4500/ 5775 batches | accuracy    0.139
# | epoch   1 |  4550/ 5775 batches | accuracy    0.143
# | epoch   1 |  4600/ 5775 batches | accuracy    0.142
# | epoch   1 |  4650/ 5775 batches | accuracy    0.134
# | epoch   1 |  4700/ 5775 batches | accuracy    0.144
# | epoch   1 |  4750/ 5775 batches | accuracy    0.132
# | epoch   1 |  4800/ 5775 batches | accuracy    0.144
# | epoch   1 |  4850/ 5775 batches | accuracy    0.152
# | epoch   1 |  4900/ 5775 batches | accuracy    0.149
# | epoch   1 |  4950/ 5775 batches | accuracy    0.150
# | epoch   1 |  5000/ 5775 batches | accuracy    0.143
# | epoch   1 |  5050/ 5775 batches | accuracy    0.158
# | epoch   1 |  5100/ 5775 batches | accuracy    0.129
# | epoch   1 |  5150/ 5775 batches | accuracy    0.133
# | epoch   1 |  5200/ 5775 batches | accuracy    0.129
# | epoch   1 |  5250/ 5775 batches | accuracy    0.158
# | epoch   1 |  5300/ 5775 batches | accuracy    0.131
# | epoch   1 |  5350/ 5775 batches | accuracy    0.147
# | epoch   1 |  5400/ 5775 batches | accuracy    0.154
# | epoch   1 |  5450/ 5775 batches | accuracy    0.146
# | epoch   1 |  5500/ 5775 batches | accuracy    0.151
# | epoch   1 |  5550/ 5775 batches | accuracy    0.162
# | epoch   1 |  5600/ 5775 batches | accuracy    0.146
# | epoch   1 |  5650/ 5775 batches | accuracy    0.152
# | epoch   1 |  5700/ 5775 batches | accuracy    0.152
# | epoch   1 |  5750/ 5775 batches | accuracy    0.139
# -----------------------------------------------------------
# | end of epoch   1 | time: 22.00s | valid accuracy    0.148
# -----------------------------------------------------------
# | epoch   2 |    50/ 5775 batches | accuracy    0.166
# | epoch   2 |   100/ 5775 batches | accuracy    0.171
# | epoch   2 |   150/ 5775 batches | accuracy    0.173
# | epoch   2 |   200/ 5775 batches | accuracy    0.153
# | epoch   2 |   250/ 5775 batches | accuracy    0.159
# | epoch   2 |   300/ 5775 batches | accuracy    0.164
# | epoch   2 |   350/ 5775 batches | accuracy    0.151
# | epoch   2 |   400/ 5775 batches | accuracy    0.178
# | epoch   2 |   450/ 5775 batches | accuracy    0.172
# | epoch   2 |   500/ 5775 batches | accuracy    0.171
# | epoch   2 |   550/ 5775 batches | accuracy    0.169
# | epoch   2 |   600/ 5775 batches | accuracy    0.172
# | epoch   2 |   650/ 5775 batches | accuracy    0.166
# | epoch   2 |   700/ 5775 batches | accuracy    0.183
# | epoch   2 |   750/ 5775 batches | accuracy    0.177
# | epoch   2 |   800/ 5775 batches | accuracy    0.156
# | epoch   2 |   850/ 5775 batches | accuracy    0.172
# | epoch   2 |   900/ 5775 batches | accuracy    0.171
# | epoch   2 |   950/ 5775 batches | accuracy    0.166
# | epoch   2 |  1000/ 5775 batches | accuracy    0.159
# | epoch   2 |  1050/ 5775 batches | accuracy    0.172
# | epoch   2 |  1100/ 5775 batches | accuracy    0.173
# | epoch   2 |  1150/ 5775 batches | accuracy    0.168
# | epoch   2 |  1200/ 5775 batches | accuracy    0.167
# | epoch   2 |  1250/ 5775 batches | accuracy    0.154
# | epoch   2 |  1300/ 5775 batches | accuracy    0.176
# | epoch   2 |  1350/ 5775 batches | accuracy    0.174
# | epoch   2 |  1400/ 5775 batches | accuracy    0.188
# | epoch   2 |  1450/ 5775 batches | accuracy    0.159
# | epoch   2 |  1500/ 5775 batches | accuracy    0.169
# | epoch   2 |  1550/ 5775 batches | accuracy    0.158
# | epoch   2 |  1600/ 5775 batches | accuracy    0.177
# | epoch   2 |  1650/ 5775 batches | accuracy    0.169
# | epoch   2 |  1700/ 5775 batches | accuracy    0.166
# | epoch   2 |  1750/ 5775 batches | accuracy    0.151
# | epoch   2 |  1800/ 5775 batches | accuracy    0.182
# | epoch   2 |  1850/ 5775 batches | accuracy    0.166
# | epoch   2 |  1900/ 5775 batches | accuracy    0.161
# | epoch   2 |  1950/ 5775 batches | accuracy    0.155
# | epoch   2 |  2000/ 5775 batches | accuracy    0.168
# | epoch   2 |  2050/ 5775 batches | accuracy    0.172
# | epoch   2 |  2100/ 5775 batches | accuracy    0.158
# | epoch   2 |  2150/ 5775 batches | accuracy    0.175
# | epoch   2 |  2200/ 5775 batches | accuracy    0.153
# | epoch   2 |  2250/ 5775 batches | accuracy    0.158
# | epoch   2 |  2300/ 5775 batches | accuracy    0.171
# | epoch   2 |  2350/ 5775 batches | accuracy    0.161
# | epoch   2 |  2400/ 5775 batches | accuracy    0.150
# | epoch   2 |  2450/ 5775 batches | accuracy    0.159
# | epoch   2 |  2500/ 5775 batches | accuracy    0.168
# | epoch   2 |  2550/ 5775 batches | accuracy    0.168
# | epoch   2 |  2600/ 5775 batches | accuracy    0.158
# | epoch   2 |  2650/ 5775 batches | accuracy    0.152
# | epoch   2 |  2700/ 5775 batches | accuracy    0.183
# | epoch   2 |  2750/ 5775 batches | accuracy    0.191
# | epoch   2 |  2800/ 5775 batches | accuracy    0.182
# | epoch   2 |  2850/ 5775 batches | accuracy    0.169
# | epoch   2 |  2900/ 5775 batches | accuracy    0.159
# | epoch   2 |  2950/ 5775 batches | accuracy    0.191
# | epoch   2 |  3000/ 5775 batches | accuracy    0.180
# | epoch   2 |  3050/ 5775 batches | accuracy    0.165
# | epoch   2 |  3100/ 5775 batches | accuracy    0.181
# | epoch   2 |  3150/ 5775 batches | accuracy    0.188
# | epoch   2 |  3200/ 5775 batches | accuracy    0.173
# | epoch   2 |  3250/ 5775 batches | accuracy    0.172
# | epoch   2 |  3300/ 5775 batches | accuracy    0.177
# | epoch   2 |  3350/ 5775 batches | accuracy    0.181
# | epoch   2 |  3400/ 5775 batches | accuracy    0.162
# | epoch   2 |  3450/ 5775 batches | accuracy    0.164
# | epoch   2 |  3500/ 5775 batches | accuracy    0.182
# | epoch   2 |  3550/ 5775 batches | accuracy    0.158
# | epoch   2 |  3600/ 5775 batches | accuracy    0.160
# | epoch   2 |  3650/ 5775 batches | accuracy    0.168
# | epoch   2 |  3700/ 5775 batches | accuracy    0.149
# | epoch   2 |  3750/ 5775 batches | accuracy    0.170
# | epoch   2 |  3800/ 5775 batches | accuracy    0.167
# | epoch   2 |  3850/ 5775 batches | accuracy    0.198
# | epoch   2 |  3900/ 5775 batches | accuracy    0.168
# | epoch   2 |  3950/ 5775 batches | accuracy    0.183
# | epoch   2 |  4000/ 5775 batches | accuracy    0.176
# | epoch   2 |  4050/ 5775 batches | accuracy    0.172
# | epoch   2 |  4100/ 5775 batches | accuracy    0.166
# | epoch   2 |  4150/ 5775 batches | accuracy    0.176
# | epoch   2 |  4200/ 5775 batches | accuracy    0.170
# | epoch   2 |  4250/ 5775 batches | accuracy    0.169
# | epoch   2 |  4300/ 5775 batches | accuracy    0.172
# | epoch   2 |  4350/ 5775 batches | accuracy    0.174
# | epoch   2 |  4400/ 5775 batches | accuracy    0.163
# | epoch   2 |  4450/ 5775 batches | accuracy    0.199
# | epoch   2 |  4500/ 5775 batches | accuracy    0.169
# | epoch   2 |  4550/ 5775 batches | accuracy    0.176
# | epoch   2 |  4600/ 5775 batches | accuracy    0.171
# | epoch   2 |  4650/ 5775 batches | accuracy    0.157
# | epoch   2 |  4700/ 5775 batches | accuracy    0.161
# | epoch   2 |  4750/ 5775 batches | accuracy    0.173
# | epoch   2 |  4800/ 5775 batches | accuracy    0.188
# | epoch   2 |  4850/ 5775 batches | accuracy    0.167
# | epoch   2 |  4900/ 5775 batches | accuracy    0.161
# | epoch   2 |  4950/ 5775 batches | accuracy    0.166
# | epoch   2 |  5000/ 5775 batches | accuracy    0.175
# | epoch   2 |  5050/ 5775 batches | accuracy    0.165
# | epoch   2 |  5100/ 5775 batches | accuracy    0.169
# | epoch   2 |  5150/ 5775 batches | accuracy    0.170
# | epoch   2 |  5200/ 5775 batches | accuracy    0.176
# | epoch   2 |  5250/ 5775 batches | accuracy    0.182
# | epoch   2 |  5300/ 5775 batches | accuracy    0.184
# | epoch   2 |  5350/ 5775 batches | accuracy    0.168
# | epoch   2 |  5400/ 5775 batches | accuracy    0.172
# | epoch   2 |  5450/ 5775 batches | accuracy    0.157
# | epoch   2 |  5500/ 5775 batches | accuracy    0.167
# | epoch   2 |  5550/ 5775 batches | accuracy    0.164
# | epoch   2 |  5600/ 5775 batches | accuracy    0.153
# | epoch   2 |  5650/ 5775 batches | accuracy    0.174
# | epoch   2 |  5700/ 5775 batches | accuracy    0.181
# | epoch   2 |  5750/ 5775 batches | accuracy    0.161
# -----------------------------------------------------------
# | end of epoch   2 | time: 21.19s | valid accuracy    0.155
# -----------------------------------------------------------
# | epoch   3 |    50/ 5775 batches | accuracy    0.222
# | epoch   3 |   100/ 5775 batches | accuracy    0.224
# | epoch   3 |   150/ 5775 batches | accuracy    0.238
# | epoch   3 |   200/ 5775 batches | accuracy    0.228
# | epoch   3 |   250/ 5775 batches | accuracy    0.229
# | epoch   3 |   300/ 5775 batches | accuracy    0.231
# | epoch   3 |   350/ 5775 batches | accuracy    0.223
# | epoch   3 |   400/ 5775 batches | accuracy    0.223
# | epoch   3 |   450/ 5775 batches | accuracy    0.256
# | epoch   3 |   500/ 5775 batches | accuracy    0.221
# | epoch   3 |   550/ 5775 batches | accuracy    0.213
# | epoch   3 |   600/ 5775 batches | accuracy    0.228
# | epoch   3 |   650/ 5775 batches | accuracy    0.241
# | epoch   3 |   700/ 5775 batches | accuracy    0.237
# | epoch   3 |   750/ 5775 batches | accuracy    0.224
# | epoch   3 |   800/ 5775 batches | accuracy    0.231
# | epoch   3 |   850/ 5775 batches | accuracy    0.230
# | epoch   3 |   900/ 5775 batches | accuracy    0.228
# | epoch   3 |   950/ 5775 batches | accuracy    0.219
# | epoch   3 |  1000/ 5775 batches | accuracy    0.226
# | epoch   3 |  1050/ 5775 batches | accuracy    0.204
# | epoch   3 |  1100/ 5775 batches | accuracy    0.233
# | epoch   3 |  1150/ 5775 batches | accuracy    0.236
# | epoch   3 |  1200/ 5775 batches | accuracy    0.219
# | epoch   3 |  1250/ 5775 batches | accuracy    0.246
# | epoch   3 |  1300/ 5775 batches | accuracy    0.232
# | epoch   3 |  1350/ 5775 batches | accuracy    0.211
# | epoch   3 |  1400/ 5775 batches | accuracy    0.224
# | epoch   3 |  1450/ 5775 batches | accuracy    0.224
# | epoch   3 |  1500/ 5775 batches | accuracy    0.212
# | epoch   3 |  1550/ 5775 batches | accuracy    0.216
# | epoch   3 |  1600/ 5775 batches | accuracy    0.231
# | epoch   3 |  1650/ 5775 batches | accuracy    0.241
# | epoch   3 |  1700/ 5775 batches | accuracy    0.224
# | epoch   3 |  1750/ 5775 batches | accuracy    0.202
# | epoch   3 |  1800/ 5775 batches | accuracy    0.202
# | epoch   3 |  1850/ 5775 batches | accuracy    0.212
# | epoch   3 |  1900/ 5775 batches | accuracy    0.222
# | epoch   3 |  1950/ 5775 batches | accuracy    0.231
# | epoch   3 |  2000/ 5775 batches | accuracy    0.236
# | epoch   3 |  2050/ 5775 batches | accuracy    0.234
# | epoch   3 |  2100/ 5775 batches | accuracy    0.217
# | epoch   3 |  2150/ 5775 batches | accuracy    0.212
# | epoch   3 |  2200/ 5775 batches | accuracy    0.212
# | epoch   3 |  2250/ 5775 batches | accuracy    0.220
# | epoch   3 |  2300/ 5775 batches | accuracy    0.217
# | epoch   3 |  2350/ 5775 batches | accuracy    0.223
# | epoch   3 |  2400/ 5775 batches | accuracy    0.220
# | epoch   3 |  2450/ 5775 batches | accuracy    0.232
# | epoch   3 |  2500/ 5775 batches | accuracy    0.230
# | epoch   3 |  2550/ 5775 batches | accuracy    0.220
# | epoch   3 |  2600/ 5775 batches | accuracy    0.211
# | epoch   3 |  2650/ 5775 batches | accuracy    0.236
# | epoch   3 |  2700/ 5775 batches | accuracy    0.235
# | epoch   3 |  2750/ 5775 batches | accuracy    0.216
# | epoch   3 |  2800/ 5775 batches | accuracy    0.202
# | epoch   3 |  2850/ 5775 batches | accuracy    0.225
# | epoch   3 |  2900/ 5775 batches | accuracy    0.232
# | epoch   3 |  2950/ 5775 batches | accuracy    0.219
# | epoch   3 |  3000/ 5775 batches | accuracy    0.198
# | epoch   3 |  3050/ 5775 batches | accuracy    0.216
# | epoch   3 |  3100/ 5775 batches | accuracy    0.228
# | epoch   3 |  3150/ 5775 batches | accuracy    0.208
# | epoch   3 |  3200/ 5775 batches | accuracy    0.207
# | epoch   3 |  3250/ 5775 batches | accuracy    0.209
# | epoch   3 |  3300/ 5775 batches | accuracy    0.212
# | epoch   3 |  3350/ 5775 batches | accuracy    0.233
# | epoch   3 |  3400/ 5775 batches | accuracy    0.231
# | epoch   3 |  3450/ 5775 batches | accuracy    0.208
# | epoch   3 |  3500/ 5775 batches | accuracy    0.217
# | epoch   3 |  3550/ 5775 batches | accuracy    0.214
# | epoch   3 |  3600/ 5775 batches | accuracy    0.228
# | epoch   3 |  3650/ 5775 batches | accuracy    0.196
# | epoch   3 |  3700/ 5775 batches | accuracy    0.215
# | epoch   3 |  3750/ 5775 batches | accuracy    0.210
# | epoch   3 |  3800/ 5775 batches | accuracy    0.233
# | epoch   3 |  3850/ 5775 batches | accuracy    0.207
# | epoch   3 |  3900/ 5775 batches | accuracy    0.232
# | epoch   3 |  3950/ 5775 batches | accuracy    0.227
# | epoch   3 |  4000/ 5775 batches | accuracy    0.231
# | epoch   3 |  4050/ 5775 batches | accuracy    0.226
# | epoch   3 |  4100/ 5775 batches | accuracy    0.206
# | epoch   3 |  4150/ 5775 batches | accuracy    0.224
# | epoch   3 |  4200/ 5775 batches | accuracy    0.226
# | epoch   3 |  4250/ 5775 batches | accuracy    0.233
# | epoch   3 |  4300/ 5775 batches | accuracy    0.235
# | epoch   3 |  4350/ 5775 batches | accuracy    0.220
# | epoch   3 |  4400/ 5775 batches | accuracy    0.219
# | epoch   3 |  4450/ 5775 batches | accuracy    0.214
# | epoch   3 |  4500/ 5775 batches | accuracy    0.212
# | epoch   3 |  4550/ 5775 batches | accuracy    0.213
# | epoch   3 |  4600/ 5775 batches | accuracy    0.219
# | epoch   3 |  4650/ 5775 batches | accuracy    0.207
# | epoch   3 |  4700/ 5775 batches | accuracy    0.220
# | epoch   3 |  4750/ 5775 batches | accuracy    0.217
# | epoch   3 |  4800/ 5775 batches | accuracy    0.214
# | epoch   3 |  4850/ 5775 batches | accuracy    0.225
# | epoch   3 |  4900/ 5775 batches | accuracy    0.214
# | epoch   3 |  4950/ 5775 batches | accuracy    0.227
# | epoch   3 |  5000/ 5775 batches | accuracy    0.222
# | epoch   3 |  5050/ 5775 batches | accuracy    0.215
# | epoch   3 |  5100/ 5775 batches | accuracy    0.229
# | epoch   3 |  5150/ 5775 batches | accuracy    0.206
# | epoch   3 |  5200/ 5775 batches | accuracy    0.215
# | epoch   3 |  5250/ 5775 batches | accuracy    0.229
# | epoch   3 |  5300/ 5775 batches | accuracy    0.207
# | epoch   3 |  5350/ 5775 batches | accuracy    0.218
# | epoch   3 |  5400/ 5775 batches | accuracy    0.212
# | epoch   3 |  5450/ 5775 batches | accuracy    0.223
# | epoch   3 |  5500/ 5775 batches | accuracy    0.223
# | epoch   3 |  5550/ 5775 batches | accuracy    0.229
# | epoch   3 |  5600/ 5775 batches | accuracy    0.217
# | epoch   3 |  5650/ 5775 batches | accuracy    0.211
# | epoch   3 |  5700/ 5775 batches | accuracy    0.233
# | epoch   3 |  5750/ 5775 batches | accuracy    0.220
# -----------------------------------------------------------
# | end of epoch   3 | time: 21.63s | valid accuracy    0.170
# -----------------------------------------------------------
# | epoch   4 |    50/ 5775 batches | accuracy    0.333
# | epoch   4 |   100/ 5775 batches | accuracy    0.329
# | epoch   4 |   150/ 5775 batches | accuracy    0.332
# | epoch   4 |   200/ 5775 batches | accuracy    0.311
# | epoch   4 |   250/ 5775 batches | accuracy    0.321
# | epoch   4 |   300/ 5775 batches | accuracy    0.329
# | epoch   4 |   350/ 5775 batches | accuracy    0.323
# | epoch   4 |   400/ 5775 batches | accuracy    0.331
# | epoch   4 |   450/ 5775 batches | accuracy    0.314
# | epoch   4 |   500/ 5775 batches | accuracy    0.311
# | epoch   4 |   550/ 5775 batches | accuracy    0.320
# | epoch   4 |   600/ 5775 batches | accuracy    0.321
# | epoch   4 |   650/ 5775 batches | accuracy    0.341
# | epoch   4 |   700/ 5775 batches | accuracy    0.315
# | epoch   4 |   750/ 5775 batches | accuracy    0.309
# | epoch   4 |   800/ 5775 batches | accuracy    0.316
# | epoch   4 |   850/ 5775 batches | accuracy    0.299
# | epoch   4 |   900/ 5775 batches | accuracy    0.304
# | epoch   4 |   950/ 5775 batches | accuracy    0.300
# | epoch   4 |  1000/ 5775 batches | accuracy    0.325
# | epoch   4 |  1050/ 5775 batches | accuracy    0.306
# | epoch   4 |  1100/ 5775 batches | accuracy    0.311
# | epoch   4 |  1150/ 5775 batches | accuracy    0.312
# | epoch   4 |  1200/ 5775 batches | accuracy    0.288
# | epoch   4 |  1250/ 5775 batches | accuracy    0.282
# | epoch   4 |  1300/ 5775 batches | accuracy    0.299
# | epoch   4 |  1350/ 5775 batches | accuracy    0.310
# | epoch   4 |  1400/ 5775 batches | accuracy    0.301
# | epoch   4 |  1450/ 5775 batches | accuracy    0.301
# | epoch   4 |  1500/ 5775 batches | accuracy    0.296
# | epoch   4 |  1550/ 5775 batches | accuracy    0.296
# | epoch   4 |  1600/ 5775 batches | accuracy    0.312
# | epoch   4 |  1650/ 5775 batches | accuracy    0.320
# | epoch   4 |  1700/ 5775 batches | accuracy    0.306
# | epoch   4 |  1750/ 5775 batches | accuracy    0.331
# | epoch   4 |  1800/ 5775 batches | accuracy    0.284
# | epoch   4 |  1850/ 5775 batches | accuracy    0.292
# | epoch   4 |  1900/ 5775 batches | accuracy    0.296
# | epoch   4 |  1950/ 5775 batches | accuracy    0.317
# | epoch   4 |  2000/ 5775 batches | accuracy    0.318
# | epoch   4 |  2050/ 5775 batches | accuracy    0.307
# | epoch   4 |  2100/ 5775 batches | accuracy    0.307
# | epoch   4 |  2150/ 5775 batches | accuracy    0.305
# | epoch   4 |  2200/ 5775 batches | accuracy    0.309
# | epoch   4 |  2250/ 5775 batches | accuracy    0.306
# | epoch   4 |  2300/ 5775 batches | accuracy    0.307
# | epoch   4 |  2350/ 5775 batches | accuracy    0.288
# | epoch   4 |  2400/ 5775 batches | accuracy    0.298
# | epoch   4 |  2450/ 5775 batches | accuracy    0.296
# | epoch   4 |  2500/ 5775 batches | accuracy    0.292
# | epoch   4 |  2550/ 5775 batches | accuracy    0.301
# | epoch   4 |  2600/ 5775 batches | accuracy    0.305
# | epoch   4 |  2650/ 5775 batches | accuracy    0.316
# | epoch   4 |  2700/ 5775 batches | accuracy    0.294
# | epoch   4 |  2750/ 5775 batches | accuracy    0.299
# | epoch   4 |  2800/ 5775 batches | accuracy    0.307
# | epoch   4 |  2850/ 5775 batches | accuracy    0.299
# | epoch   4 |  2900/ 5775 batches | accuracy    0.301
# | epoch   4 |  2950/ 5775 batches | accuracy    0.263
# | epoch   4 |  3000/ 5775 batches | accuracy    0.291
# | epoch   4 |  3050/ 5775 batches | accuracy    0.287
# | epoch   4 |  3100/ 5775 batches | accuracy    0.293
# | epoch   4 |  3150/ 5775 batches | accuracy    0.294
# | epoch   4 |  3200/ 5775 batches | accuracy    0.259
# | epoch   4 |  3250/ 5775 batches | accuracy    0.273
# | epoch   4 |  3300/ 5775 batches | accuracy    0.279
# | epoch   4 |  3350/ 5775 batches | accuracy    0.307
# | epoch   4 |  3400/ 5775 batches | accuracy    0.295
# | epoch   4 |  3450/ 5775 batches | accuracy    0.286
# | epoch   4 |  3500/ 5775 batches | accuracy    0.276
# | epoch   4 |  3550/ 5775 batches | accuracy    0.312
# | epoch   4 |  3600/ 5775 batches | accuracy    0.307
# | epoch   4 |  3650/ 5775 batches | accuracy    0.286
# | epoch   4 |  3700/ 5775 batches | accuracy    0.299
# | epoch   4 |  3750/ 5775 batches | accuracy    0.281
# | epoch   4 |  3800/ 5775 batches | accuracy    0.292
# | epoch   4 |  3850/ 5775 batches | accuracy    0.256
# | epoch   4 |  3900/ 5775 batches | accuracy    0.287
# | epoch   4 |  3950/ 5775 batches | accuracy    0.297
# | epoch   4 |  4000/ 5775 batches | accuracy    0.291
# | epoch   4 |  4050/ 5775 batches | accuracy    0.283
# | epoch   4 |  4100/ 5775 batches | accuracy    0.325
# | epoch   4 |  4150/ 5775 batches | accuracy    0.263
# | epoch   4 |  4200/ 5775 batches | accuracy    0.297
# | epoch   4 |  4250/ 5775 batches | accuracy    0.274
# | epoch   4 |  4300/ 5775 batches | accuracy    0.276
# | epoch   4 |  4350/ 5775 batches | accuracy    0.318
# | epoch   4 |  4400/ 5775 batches | accuracy    0.294
# | epoch   4 |  4450/ 5775 batches | accuracy    0.301
# | epoch   4 |  4500/ 5775 batches | accuracy    0.267
# | epoch   4 |  4550/ 5775 batches | accuracy    0.272
# | epoch   4 |  4600/ 5775 batches | accuracy    0.296
# | epoch   4 |  4650/ 5775 batches | accuracy    0.271
# | epoch   4 |  4700/ 5775 batches | accuracy    0.303
# | epoch   4 |  4750/ 5775 batches | accuracy    0.276
# | epoch   4 |  4800/ 5775 batches | accuracy    0.271
# | epoch   4 |  4850/ 5775 batches | accuracy    0.270
# | epoch   4 |  4900/ 5775 batches | accuracy    0.294
# | epoch   4 |  4950/ 5775 batches | accuracy    0.278
# | epoch   4 |  5000/ 5775 batches | accuracy    0.310
# | epoch   4 |  5050/ 5775 batches | accuracy    0.279
# | epoch   4 |  5100/ 5775 batches | accuracy    0.280
# | epoch   4 |  5150/ 5775 batches | accuracy    0.306
# | epoch   4 |  5200/ 5775 batches | accuracy    0.278
# | epoch   4 |  5250/ 5775 batches | accuracy    0.282
# | epoch   4 |  5300/ 5775 batches | accuracy    0.309
# | epoch   4 |  5350/ 5775 batches | accuracy    0.271
# | epoch   4 |  5400/ 5775 batches | accuracy    0.279
# | epoch   4 |  5450/ 5775 batches | accuracy    0.272
# | epoch   4 |  5500/ 5775 batches | accuracy    0.268
# | epoch   4 |  5550/ 5775 batches | accuracy    0.276
# | epoch   4 |  5600/ 5775 batches | accuracy    0.263
# | epoch   4 |  5650/ 5775 batches | accuracy    0.306
# | epoch   4 |  5700/ 5775 batches | accuracy    0.276
# | epoch   4 |  5750/ 5775 batches | accuracy    0.280
# -----------------------------------------------------------
# | end of epoch   4 | time: 21.07s | valid accuracy    0.170
# -----------------------------------------------------------
# | epoch   5 |    50/ 5775 batches | accuracy    0.388
# | epoch   5 |   100/ 5775 batches | accuracy    0.426
# | epoch   5 |   150/ 5775 batches | accuracy    0.413
# | epoch   5 |   200/ 5775 batches | accuracy    0.410
# | epoch   5 |   250/ 5775 batches | accuracy    0.392
# | epoch   5 |   300/ 5775 batches | accuracy    0.404
# | epoch   5 |   350/ 5775 batches | accuracy    0.402
# | epoch   5 |   400/ 5775 batches | accuracy    0.396
# | epoch   5 |   450/ 5775 batches | accuracy    0.399
# | epoch   5 |   500/ 5775 batches | accuracy    0.393
# | epoch   5 |   550/ 5775 batches | accuracy    0.380
# | epoch   5 |   600/ 5775 batches | accuracy    0.367
# | epoch   5 |   650/ 5775 batches | accuracy    0.398
# | epoch   5 |   700/ 5775 batches | accuracy    0.386
# | epoch   5 |   750/ 5775 batches | accuracy    0.380
# | epoch   5 |   800/ 5775 batches | accuracy    0.393
# | epoch   5 |   850/ 5775 batches | accuracy    0.405
# | epoch   5 |   900/ 5775 batches | accuracy    0.387
# | epoch   5 |   950/ 5775 batches | accuracy    0.364
# | epoch   5 |  1000/ 5775 batches | accuracy    0.384
# | epoch   5 |  1050/ 5775 batches | accuracy    0.369
# | epoch   5 |  1100/ 5775 batches | accuracy    0.403
# | epoch   5 |  1150/ 5775 batches | accuracy    0.382
# | epoch   5 |  1200/ 5775 batches | accuracy    0.388
# | epoch   5 |  1250/ 5775 batches | accuracy    0.394
# | epoch   5 |  1300/ 5775 batches | accuracy    0.394
# | epoch   5 |  1350/ 5775 batches | accuracy    0.378
# | epoch   5 |  1400/ 5775 batches | accuracy    0.373
# | epoch   5 |  1450/ 5775 batches | accuracy    0.359
# | epoch   5 |  1500/ 5775 batches | accuracy    0.363
# | epoch   5 |  1550/ 5775 batches | accuracy    0.376
# | epoch   5 |  1600/ 5775 batches | accuracy    0.371
# | epoch   5 |  1650/ 5775 batches | accuracy    0.394
# | epoch   5 |  1700/ 5775 batches | accuracy    0.381
# | epoch   5 |  1750/ 5775 batches | accuracy    0.366
# | epoch   5 |  1800/ 5775 batches | accuracy    0.379
# | epoch   5 |  1850/ 5775 batches | accuracy    0.388
# | epoch   5 |  1900/ 5775 batches | accuracy    0.378
# | epoch   5 |  1950/ 5775 batches | accuracy    0.367
# | epoch   5 |  2000/ 5775 batches | accuracy    0.385
# | epoch   5 |  2050/ 5775 batches | accuracy    0.388
# | epoch   5 |  2100/ 5775 batches | accuracy    0.355
# | epoch   5 |  2150/ 5775 batches | accuracy    0.381
# | epoch   5 |  2200/ 5775 batches | accuracy    0.352
# | epoch   5 |  2250/ 5775 batches | accuracy    0.372
# | epoch   5 |  2300/ 5775 batches | accuracy    0.369
# | epoch   5 |  2350/ 5775 batches | accuracy    0.354
# | epoch   5 |  2400/ 5775 batches | accuracy    0.391
# | epoch   5 |  2450/ 5775 batches | accuracy    0.357
# | epoch   5 |  2500/ 5775 batches | accuracy    0.371
# | epoch   5 |  2550/ 5775 batches | accuracy    0.384
# | epoch   5 |  2600/ 5775 batches | accuracy    0.396
# | epoch   5 |  2650/ 5775 batches | accuracy    0.384
# | epoch   5 |  2700/ 5775 batches | accuracy    0.353
# | epoch   5 |  2750/ 5775 batches | accuracy    0.364
# | epoch   5 |  2800/ 5775 batches | accuracy    0.357
# | epoch   5 |  2850/ 5775 batches | accuracy    0.360
# | epoch   5 |  2900/ 5775 batches | accuracy    0.383
# | epoch   5 |  2950/ 5775 batches | accuracy    0.359
# | epoch   5 |  3000/ 5775 batches | accuracy    0.356
# | epoch   5 |  3050/ 5775 batches | accuracy    0.364
# | epoch   5 |  3100/ 5775 batches | accuracy    0.374
# | epoch   5 |  3150/ 5775 batches | accuracy    0.347
# | epoch   5 |  3200/ 5775 batches | accuracy    0.376
# | epoch   5 |  3250/ 5775 batches | accuracy    0.366
# | epoch   5 |  3300/ 5775 batches | accuracy    0.371
# | epoch   5 |  3350/ 5775 batches | accuracy    0.358
# | epoch   5 |  3400/ 5775 batches | accuracy    0.355
# | epoch   5 |  3450/ 5775 batches | accuracy    0.359
# | epoch   5 |  3500/ 5775 batches | accuracy    0.358
# | epoch   5 |  3550/ 5775 batches | accuracy    0.347
# | epoch   5 |  3600/ 5775 batches | accuracy    0.384
# | epoch   5 |  3650/ 5775 batches | accuracy    0.350
# | epoch   5 |  3700/ 5775 batches | accuracy    0.379
# | epoch   5 |  3750/ 5775 batches | accuracy    0.338
# | epoch   5 |  3800/ 5775 batches | accuracy    0.366
# | epoch   5 |  3850/ 5775 batches | accuracy    0.360
# | epoch   5 |  3900/ 5775 batches | accuracy    0.361
# | epoch   5 |  3950/ 5775 batches | accuracy    0.359
# | epoch   5 |  4000/ 5775 batches | accuracy    0.349
# | epoch   5 |  4050/ 5775 batches | accuracy    0.351
# | epoch   5 |  4100/ 5775 batches | accuracy    0.375
# | epoch   5 |  4150/ 5775 batches | accuracy    0.346
# | epoch   5 |  4200/ 5775 batches | accuracy    0.369
# | epoch   5 |  4250/ 5775 batches | accuracy    0.350
# | epoch   5 |  4300/ 5775 batches | accuracy    0.342
# | epoch   5 |  4350/ 5775 batches | accuracy    0.348
# | epoch   5 |  4400/ 5775 batches | accuracy    0.364
# | epoch   5 |  4450/ 5775 batches | accuracy    0.354
# | epoch   5 |  4500/ 5775 batches | accuracy    0.341
# | epoch   5 |  4550/ 5775 batches | accuracy    0.355
# | epoch   5 |  4600/ 5775 batches | accuracy    0.338
# | epoch   5 |  4650/ 5775 batches | accuracy    0.344
# | epoch   5 |  4700/ 5775 batches | accuracy    0.347
# | epoch   5 |  4750/ 5775 batches | accuracy    0.355
# | epoch   5 |  4800/ 5775 batches | accuracy    0.356
# | epoch   5 |  4850/ 5775 batches | accuracy    0.341
# | epoch   5 |  4900/ 5775 batches | accuracy    0.346
# | epoch   5 |  4950/ 5775 batches | accuracy    0.349
# | epoch   5 |  5000/ 5775 batches | accuracy    0.342
# | epoch   5 |  5050/ 5775 batches | accuracy    0.351
# | epoch   5 |  5100/ 5775 batches | accuracy    0.370
# | epoch   5 |  5150/ 5775 batches | accuracy    0.365
# | epoch   5 |  5200/ 5775 batches | accuracy    0.349
# | epoch   5 |  5250/ 5775 batches | accuracy    0.352
# | epoch   5 |  5300/ 5775 batches | accuracy    0.370
# | epoch   5 |  5350/ 5775 batches | accuracy    0.359
# | epoch   5 |  5400/ 5775 batches | accuracy    0.351
# | epoch   5 |  5450/ 5775 batches | accuracy    0.368
# | epoch   5 |  5500/ 5775 batches | accuracy    0.355
# | epoch   5 |  5550/ 5775 batches | accuracy    0.357
# | epoch   5 |  5600/ 5775 batches | accuracy    0.343
# | epoch   5 |  5650/ 5775 batches | accuracy    0.339
# | epoch   5 |  5700/ 5775 batches | accuracy    0.334
# | epoch   5 |  5750/ 5775 batches | accuracy    0.344
# -----------------------------------------------------------
# | end of epoch   5 | time: 21.05s | valid accuracy    0.181
# -----------------------------------------------------------
# | epoch   6 |    50/ 5775 batches | accuracy    0.454
# | epoch   6 |   100/ 5775 batches | accuracy    0.459
# | epoch   6 |   150/ 5775 batches | accuracy    0.451
# | epoch   6 |   200/ 5775 batches | accuracy    0.455
# | epoch   6 |   250/ 5775 batches | accuracy    0.470
# | epoch   6 |   300/ 5775 batches | accuracy    0.453
# | epoch   6 |   350/ 5775 batches | accuracy    0.456
# | epoch   6 |   400/ 5775 batches | accuracy    0.444
# | epoch   6 |   450/ 5775 batches | accuracy    0.459
# | epoch   6 |   500/ 5775 batches | accuracy    0.455
# | epoch   6 |   550/ 5775 batches | accuracy    0.450
# | epoch   6 |   600/ 5775 batches | accuracy    0.444
# | epoch   6 |   650/ 5775 batches | accuracy    0.449
# | epoch   6 |   700/ 5775 batches | accuracy    0.436
# | epoch   6 |   750/ 5775 batches | accuracy    0.431
# | epoch   6 |   800/ 5775 batches | accuracy    0.451
# | epoch   6 |   850/ 5775 batches | accuracy    0.434
# | epoch   6 |   900/ 5775 batches | accuracy    0.436
# | epoch   6 |   950/ 5775 batches | accuracy    0.432
# | epoch   6 |  1000/ 5775 batches | accuracy    0.450
# | epoch   6 |  1050/ 5775 batches | accuracy    0.434
# | epoch   6 |  1100/ 5775 batches | accuracy    0.442
# | epoch   6 |  1150/ 5775 batches | accuracy    0.439
# | epoch   6 |  1200/ 5775 batches | accuracy    0.414
# | epoch   6 |  1250/ 5775 batches | accuracy    0.448
# | epoch   6 |  1300/ 5775 batches | accuracy    0.423
# | epoch   6 |  1350/ 5775 batches | accuracy    0.431
# | epoch   6 |  1400/ 5775 batches | accuracy    0.411
# | epoch   6 |  1450/ 5775 batches | accuracy    0.440
# | epoch   6 |  1500/ 5775 batches | accuracy    0.431
# | epoch   6 |  1550/ 5775 batches | accuracy    0.425
# | epoch   6 |  1600/ 5775 batches | accuracy    0.413
# | epoch   6 |  1650/ 5775 batches | accuracy    0.436
# | epoch   6 |  1700/ 5775 batches | accuracy    0.408
# | epoch   6 |  1750/ 5775 batches | accuracy    0.422
# | epoch   6 |  1800/ 5775 batches | accuracy    0.412
# | epoch   6 |  1850/ 5775 batches | accuracy    0.411
# | epoch   6 |  1900/ 5775 batches | accuracy    0.422
# | epoch   6 |  1950/ 5775 batches | accuracy    0.440
# | epoch   6 |  2000/ 5775 batches | accuracy    0.432
# | epoch   6 |  2050/ 5775 batches | accuracy    0.406
# | epoch   6 |  2100/ 5775 batches | accuracy    0.412
# | epoch   6 |  2150/ 5775 batches | accuracy    0.423
# | epoch   6 |  2200/ 5775 batches | accuracy    0.416
# | epoch   6 |  2250/ 5775 batches | accuracy    0.423
# | epoch   6 |  2300/ 5775 batches | accuracy    0.436
# | epoch   6 |  2350/ 5775 batches | accuracy    0.405
# | epoch   6 |  2400/ 5775 batches | accuracy    0.404
# | epoch   6 |  2450/ 5775 batches | accuracy    0.414
# | epoch   6 |  2500/ 5775 batches | accuracy    0.411
# | epoch   6 |  2550/ 5775 batches | accuracy    0.431
# | epoch   6 |  2600/ 5775 batches | accuracy    0.402
# | epoch   6 |  2650/ 5775 batches | accuracy    0.405
# | epoch   6 |  2700/ 5775 batches | accuracy    0.419
# | epoch   6 |  2750/ 5775 batches | accuracy    0.404
# | epoch   6 |  2800/ 5775 batches | accuracy    0.421
# | epoch   6 |  2850/ 5775 batches | accuracy    0.425
# | epoch   6 |  2900/ 5775 batches | accuracy    0.424
# | epoch   6 |  2950/ 5775 batches | accuracy    0.427
# | epoch   6 |  3000/ 5775 batches | accuracy    0.405
# | epoch   6 |  3050/ 5775 batches | accuracy    0.396
# | epoch   6 |  3100/ 5775 batches | accuracy    0.424
# | epoch   6 |  3150/ 5775 batches | accuracy    0.427
# | epoch   6 |  3200/ 5775 batches | accuracy    0.391
# | epoch   6 |  3250/ 5775 batches | accuracy    0.404
# | epoch   6 |  3300/ 5775 batches | accuracy    0.397
# | epoch   6 |  3350/ 5775 batches | accuracy    0.395
# | epoch   6 |  3400/ 5775 batches | accuracy    0.426
# | epoch   6 |  3450/ 5775 batches | accuracy    0.425
# | epoch   6 |  3500/ 5775 batches | accuracy    0.407
# | epoch   6 |  3550/ 5775 batches | accuracy    0.411
# | epoch   6 |  3600/ 5775 batches | accuracy    0.383
# | epoch   6 |  3650/ 5775 batches | accuracy    0.405
# | epoch   6 |  3700/ 5775 batches | accuracy    0.414
# | epoch   6 |  3750/ 5775 batches | accuracy    0.402
# | epoch   6 |  3800/ 5775 batches | accuracy    0.420
# | epoch   6 |  3850/ 5775 batches | accuracy    0.410
# | epoch   6 |  3900/ 5775 batches | accuracy    0.412
# | epoch   6 |  3950/ 5775 batches | accuracy    0.424
# | epoch   6 |  4000/ 5775 batches | accuracy    0.403
# | epoch   6 |  4050/ 5775 batches | accuracy    0.399
# | epoch   6 |  4100/ 5775 batches | accuracy    0.400
# | epoch   6 |  4150/ 5775 batches | accuracy    0.416
# | epoch   6 |  4200/ 5775 batches | accuracy    0.403
# | epoch   6 |  4250/ 5775 batches | accuracy    0.391
# | epoch   6 |  4300/ 5775 batches | accuracy    0.384
# | epoch   6 |  4350/ 5775 batches | accuracy    0.404
# | epoch   6 |  4400/ 5775 batches | accuracy    0.400
# | epoch   6 |  4450/ 5775 batches | accuracy    0.383
# | epoch   6 |  4500/ 5775 batches | accuracy    0.396
# | epoch   6 |  4550/ 5775 batches | accuracy    0.398
# | epoch   6 |  4600/ 5775 batches | accuracy    0.386
# | epoch   6 |  4650/ 5775 batches | accuracy    0.397
# | epoch   6 |  4700/ 5775 batches | accuracy    0.387
# | epoch   6 |  4750/ 5775 batches | accuracy    0.393
# | epoch   6 |  4800/ 5775 batches | accuracy    0.407
# | epoch   6 |  4850/ 5775 batches | accuracy    0.389
# | epoch   6 |  4900/ 5775 batches | accuracy    0.424
# | epoch   6 |  4950/ 5775 batches | accuracy    0.383
# | epoch   6 |  5000/ 5775 batches | accuracy    0.399
# | epoch   6 |  5050/ 5775 batches | accuracy    0.395
# | epoch   6 |  5100/ 5775 batches | accuracy    0.394
# | epoch   6 |  5150/ 5775 batches | accuracy    0.404
# | epoch   6 |  5200/ 5775 batches | accuracy    0.394
# | epoch   6 |  5250/ 5775 batches | accuracy    0.404
# | epoch   6 |  5300/ 5775 batches | accuracy    0.386
# | epoch   6 |  5350/ 5775 batches | accuracy    0.384
# | epoch   6 |  5400/ 5775 batches | accuracy    0.389
# | epoch   6 |  5450/ 5775 batches | accuracy    0.381
# | epoch   6 |  5500/ 5775 batches | accuracy    0.399
# | epoch   6 |  5550/ 5775 batches | accuracy    0.370
# | epoch   6 |  5600/ 5775 batches | accuracy    0.389
# | epoch   6 |  5650/ 5775 batches | accuracy    0.394
# | epoch   6 |  5700/ 5775 batches | accuracy    0.390
# | epoch   6 |  5750/ 5775 batches | accuracy    0.381
# -----------------------------------------------------------
# | end of epoch   6 | time: 20.86s | valid accuracy    0.175
# -----------------------------------------------------------
# | epoch   7 |    50/ 5775 batches | accuracy    0.480
# | epoch   7 |   100/ 5775 batches | accuracy    0.482
# | epoch   7 |   150/ 5775 batches | accuracy    0.509
# | epoch   7 |   200/ 5775 batches | accuracy    0.509
# | epoch   7 |   250/ 5775 batches | accuracy    0.515
# | epoch   7 |   300/ 5775 batches | accuracy    0.509
# | epoch   7 |   350/ 5775 batches | accuracy    0.536
# | epoch   7 |   400/ 5775 batches | accuracy    0.509
# | epoch   7 |   450/ 5775 batches | accuracy    0.524
# | epoch   7 |   500/ 5775 batches | accuracy    0.530
# | epoch   7 |   550/ 5775 batches | accuracy    0.521
# | epoch   7 |   600/ 5775 batches | accuracy    0.502
# | epoch   7 |   650/ 5775 batches | accuracy    0.508
# | epoch   7 |   700/ 5775 batches | accuracy    0.524
# | epoch   7 |   750/ 5775 batches | accuracy    0.511
# | epoch   7 |   800/ 5775 batches | accuracy    0.521
# | epoch   7 |   850/ 5775 batches | accuracy    0.535
# | epoch   7 |   900/ 5775 batches | accuracy    0.531
# | epoch   7 |   950/ 5775 batches | accuracy    0.521
# | epoch   7 |  1000/ 5775 batches | accuracy    0.507
# | epoch   7 |  1050/ 5775 batches | accuracy    0.526
# | epoch   7 |  1100/ 5775 batches | accuracy    0.534
# | epoch   7 |  1150/ 5775 batches | accuracy    0.512
# | epoch   7 |  1200/ 5775 batches | accuracy    0.522
# | epoch   7 |  1250/ 5775 batches | accuracy    0.526
# | epoch   7 |  1300/ 5775 batches | accuracy    0.521
# | epoch   7 |  1350/ 5775 batches | accuracy    0.526
# | epoch   7 |  1400/ 5775 batches | accuracy    0.496
# | epoch   7 |  1450/ 5775 batches | accuracy    0.493
# | epoch   7 |  1500/ 5775 batches | accuracy    0.534
# | epoch   7 |  1550/ 5775 batches | accuracy    0.512
# | epoch   7 |  1600/ 5775 batches | accuracy    0.501
# | epoch   7 |  1650/ 5775 batches | accuracy    0.523
# | epoch   7 |  1700/ 5775 batches | accuracy    0.522
# | epoch   7 |  1750/ 5775 batches | accuracy    0.516
# | epoch   7 |  1800/ 5775 batches | accuracy    0.522
# | epoch   7 |  1850/ 5775 batches | accuracy    0.526
# | epoch   7 |  1900/ 5775 batches | accuracy    0.501
# | epoch   7 |  1950/ 5775 batches | accuracy    0.508
# | epoch   7 |  2000/ 5775 batches | accuracy    0.511
# | epoch   7 |  2050/ 5775 batches | accuracy    0.517
# | epoch   7 |  2100/ 5775 batches | accuracy    0.526
# | epoch   7 |  2150/ 5775 batches | accuracy    0.531
# | epoch   7 |  2200/ 5775 batches | accuracy    0.526
# | epoch   7 |  2250/ 5775 batches | accuracy    0.537
# | epoch   7 |  2300/ 5775 batches | accuracy    0.511
# | epoch   7 |  2350/ 5775 batches | accuracy    0.513
# | epoch   7 |  2400/ 5775 batches | accuracy    0.523
# | epoch   7 |  2450/ 5775 batches | accuracy    0.538
# | epoch   7 |  2500/ 5775 batches | accuracy    0.517
# | epoch   7 |  2550/ 5775 batches | accuracy    0.531
# | epoch   7 |  2600/ 5775 batches | accuracy    0.534
# | epoch   7 |  2650/ 5775 batches | accuracy    0.518
# | epoch   7 |  2700/ 5775 batches | accuracy    0.522
# | epoch   7 |  2750/ 5775 batches | accuracy    0.512
# | epoch   7 |  2800/ 5775 batches | accuracy    0.511
# | epoch   7 |  2850/ 5775 batches | accuracy    0.518
# | epoch   7 |  2900/ 5775 batches | accuracy    0.514
# | epoch   7 |  2950/ 5775 batches | accuracy    0.534
# | epoch   7 |  3000/ 5775 batches | accuracy    0.522
# | epoch   7 |  3050/ 5775 batches | accuracy    0.527
# | epoch   7 |  3100/ 5775 batches | accuracy    0.484
# | epoch   7 |  3150/ 5775 batches | accuracy    0.519
# | epoch   7 |  3200/ 5775 batches | accuracy    0.506
# | epoch   7 |  3250/ 5775 batches | accuracy    0.509
# | epoch   7 |  3300/ 5775 batches | accuracy    0.517
# | epoch   7 |  3350/ 5775 batches | accuracy    0.512
# | epoch   7 |  3400/ 5775 batches | accuracy    0.530
# | epoch   7 |  3450/ 5775 batches | accuracy    0.532
# | epoch   7 |  3500/ 5775 batches | accuracy    0.521
# | epoch   7 |  3550/ 5775 batches | accuracy    0.527
# | epoch   7 |  3600/ 5775 batches | accuracy    0.515
# | epoch   7 |  3650/ 5775 batches | accuracy    0.506
# | epoch   7 |  3700/ 5775 batches | accuracy    0.497
# | epoch   7 |  3750/ 5775 batches | accuracy    0.535
# | epoch   7 |  3800/ 5775 batches | accuracy    0.518
# | epoch   7 |  3850/ 5775 batches | accuracy    0.509
# | epoch   7 |  3900/ 5775 batches | accuracy    0.504
# | epoch   7 |  3950/ 5775 batches | accuracy    0.535
# | epoch   7 |  4000/ 5775 batches | accuracy    0.521
# | epoch   7 |  4050/ 5775 batches | accuracy    0.518
# | epoch   7 |  4100/ 5775 batches | accuracy    0.531
# | epoch   7 |  4150/ 5775 batches | accuracy    0.504
# | epoch   7 |  4200/ 5775 batches | accuracy    0.516
# | epoch   7 |  4250/ 5775 batches | accuracy    0.542
# | epoch   7 |  4300/ 5775 batches | accuracy    0.522
# | epoch   7 |  4350/ 5775 batches | accuracy    0.533
# | epoch   7 |  4400/ 5775 batches | accuracy    0.527
# | epoch   7 |  4450/ 5775 batches | accuracy    0.504
# | epoch   7 |  4500/ 5775 batches | accuracy    0.513
# | epoch   7 |  4550/ 5775 batches | accuracy    0.510
# | epoch   7 |  4600/ 5775 batches | accuracy    0.531
# | epoch   7 |  4650/ 5775 batches | accuracy    0.513
# | epoch   7 |  4700/ 5775 batches | accuracy    0.542
# | epoch   7 |  4750/ 5775 batches | accuracy    0.508
# | epoch   7 |  4800/ 5775 batches | accuracy    0.521
# | epoch   7 |  4850/ 5775 batches | accuracy    0.521
# | epoch   7 |  4900/ 5775 batches | accuracy    0.492
# | epoch   7 |  4950/ 5775 batches | accuracy    0.525
# | epoch   7 |  5000/ 5775 batches | accuracy    0.529
# | epoch   7 |  5050/ 5775 batches | accuracy    0.522
# | epoch   7 |  5100/ 5775 batches | accuracy    0.498
# | epoch   7 |  5150/ 5775 batches | accuracy    0.524
# | epoch   7 |  5200/ 5775 batches | accuracy    0.514
# | epoch   7 |  5250/ 5775 batches | accuracy    0.525
# | epoch   7 |  5300/ 5775 batches | accuracy    0.522
# | epoch   7 |  5350/ 5775 batches | accuracy    0.491
# | epoch   7 |  5400/ 5775 batches | accuracy    0.538
# | epoch   7 |  5450/ 5775 batches | accuracy    0.520
# | epoch   7 |  5500/ 5775 batches | accuracy    0.532
# | epoch   7 |  5550/ 5775 batches | accuracy    0.484
# | epoch   7 |  5600/ 5775 batches | accuracy    0.511
# | epoch   7 |  5650/ 5775 batches | accuracy    0.514
# | epoch   7 |  5700/ 5775 batches | accuracy    0.534
# | epoch   7 |  5750/ 5775 batches | accuracy    0.502
# -----------------------------------------------------------
# | end of epoch   7 | time: 20.91s | valid accuracy    0.186
# -----------------------------------------------------------
# | epoch   8 |    50/ 5775 batches | accuracy    0.548
# | epoch   8 |   100/ 5775 batches | accuracy    0.547
# | epoch   8 |   150/ 5775 batches | accuracy    0.515
# | epoch   8 |   200/ 5775 batches | accuracy    0.513
# | epoch   8 |   250/ 5775 batches | accuracy    0.526
# | epoch   8 |   300/ 5775 batches | accuracy    0.533
# | epoch   8 |   350/ 5775 batches | accuracy    0.531
# | epoch   8 |   400/ 5775 batches | accuracy    0.529
# | epoch   8 |   450/ 5775 batches | accuracy    0.528
# | epoch   8 |   500/ 5775 batches | accuracy    0.537
# | epoch   8 |   550/ 5775 batches | accuracy    0.537
# | epoch   8 |   600/ 5775 batches | accuracy    0.505
# | epoch   8 |   650/ 5775 batches | accuracy    0.540
# | epoch   8 |   700/ 5775 batches | accuracy    0.528
# | epoch   8 |   750/ 5775 batches | accuracy    0.532
# | epoch   8 |   800/ 5775 batches | accuracy    0.518
# | epoch   8 |   850/ 5775 batches | accuracy    0.532
# | epoch   8 |   900/ 5775 batches | accuracy    0.535
# | epoch   8 |   950/ 5775 batches | accuracy    0.541
# | epoch   8 |  1000/ 5775 batches | accuracy    0.531
# | epoch   8 |  1050/ 5775 batches | accuracy    0.530
# | epoch   8 |  1100/ 5775 batches | accuracy    0.541
# | epoch   8 |  1150/ 5775 batches | accuracy    0.524
# | epoch   8 |  1200/ 5775 batches | accuracy    0.536
# | epoch   8 |  1250/ 5775 batches | accuracy    0.524
# | epoch   8 |  1300/ 5775 batches | accuracy    0.513
# | epoch   8 |  1350/ 5775 batches | accuracy    0.541
# | epoch   8 |  1400/ 5775 batches | accuracy    0.534
# | epoch   8 |  1450/ 5775 batches | accuracy    0.531
# | epoch   8 |  1500/ 5775 batches | accuracy    0.521
# | epoch   8 |  1550/ 5775 batches | accuracy    0.512
# | epoch   8 |  1600/ 5775 batches | accuracy    0.536
# | epoch   8 |  1650/ 5775 batches | accuracy    0.524
# | epoch   8 |  1700/ 5775 batches | accuracy    0.536
# | epoch   8 |  1750/ 5775 batches | accuracy    0.521
# | epoch   8 |  1800/ 5775 batches | accuracy    0.517
# | epoch   8 |  1850/ 5775 batches | accuracy    0.514
# | epoch   8 |  1900/ 5775 batches | accuracy    0.559
# | epoch   8 |  1950/ 5775 batches | accuracy    0.533
# | epoch   8 |  2000/ 5775 batches | accuracy    0.531
# | epoch   8 |  2050/ 5775 batches | accuracy    0.529
# | epoch   8 |  2100/ 5775 batches | accuracy    0.519
# | epoch   8 |  2150/ 5775 batches | accuracy    0.538
# | epoch   8 |  2200/ 5775 batches | accuracy    0.529
# | epoch   8 |  2250/ 5775 batches | accuracy    0.495
# | epoch   8 |  2300/ 5775 batches | accuracy    0.521
# | epoch   8 |  2350/ 5775 batches | accuracy    0.541
# | epoch   8 |  2400/ 5775 batches | accuracy    0.537
# | epoch   8 |  2450/ 5775 batches | accuracy    0.520
# | epoch   8 |  2500/ 5775 batches | accuracy    0.514
# | epoch   8 |  2550/ 5775 batches | accuracy    0.521
# | epoch   8 |  2600/ 5775 batches | accuracy    0.511
# | epoch   8 |  2650/ 5775 batches | accuracy    0.536
# | epoch   8 |  2700/ 5775 batches | accuracy    0.507
# | epoch   8 |  2750/ 5775 batches | accuracy    0.515
# | epoch   8 |  2800/ 5775 batches | accuracy    0.523
# | epoch   8 |  2850/ 5775 batches | accuracy    0.524
# | epoch   8 |  2900/ 5775 batches | accuracy    0.530
# | epoch   8 |  2950/ 5775 batches | accuracy    0.523
# | epoch   8 |  3000/ 5775 batches | accuracy    0.499
# ...
# | epoch  18 |  3000/ 5775 batches | accuracy    0.569
# | epoch  18 |  3050/ 5775 batches | accuracy    0.554
# | epoch  18 |  3100/ 5775 batches | accuracy    0.558
# | epoch  18 |  3150/ 5775 batches | accuracy    0.557
# | epoch  18 |  3200/ 5775 batches | accuracy    0.534
# | epoch  18 |  3250/ 5775 batches | accuracy    0.550
# | epoch  18 |  3300/ 5775 batches | accuracy    0.566
# | epoch  18 |  3350/ 5775 batches | accuracy    0.546
# | epoch  18 |  3400/ 5775 batches | accuracy    0.544
# | epoch  18 |  3450/ 5775 batches | accuracy    0.534
# | epoch  18 |  3500/ 5775 batches | accuracy    0.553
# | epoch  18 |  3550/ 5775 batches | accuracy    0.554
# | epoch  18 |  3600/ 5775 batches | accuracy    0.543
# | epoch  18 |  3650/ 5775 batches | accuracy    0.554
# | epoch  18 |  3700/ 5775 batches | accuracy    0.561
# | epoch  18 |  3750/ 5775 batches | accuracy    0.586
# | epoch  18 |  3800/ 5775 batches | accuracy    0.542
# | epoch  18 |  3850/ 5775 batches | accuracy    0.549
# | epoch  18 |  3900/ 5775 batches | accuracy    0.546
# | epoch  18 |  3950/ 5775 batches | accuracy    0.554
# | epoch  18 |  4000/ 5775 batches | accuracy    0.542
# | epoch  18 |  4050/ 5775 batches | accuracy    0.535
# | epoch  18 |  4100/ 5775 batches | accuracy    0.537
# | epoch  18 |  4150/ 5775 batches | accuracy    0.538
# | epoch  18 |  4200/ 5775 batches | accuracy    0.558
# | epoch  18 |  4250/ 5775 batches | accuracy    0.547
# | epoch  18 |  4300/ 5775 batches | accuracy    0.529
# | epoch  18 |  4350/ 5775 batches | accuracy    0.539
# | epoch  18 |  4400/ 5775 batches | accuracy    0.550
# | epoch  18 |  4450/ 5775 batches | accuracy    0.546
# | epoch  18 |  4500/ 5775 batches | accuracy    0.539
# | epoch  18 |  4550/ 5775 batches | accuracy    0.551
# | epoch  18 |  4600/ 5775 batches | accuracy    0.552
# | epoch  18 |  4650/ 5775 batches | accuracy    0.562
# | epoch  18 |  4700/ 5775 batches | accuracy    0.561
# | epoch  18 |  4750/ 5775 batches | accuracy    0.547
# | epoch  18 |  4800/ 5775 batches | accuracy    0.548
# | epoch  18 |  4850/ 5775 batches | accuracy    0.561
# | epoch  18 |  4900/ 5775 batches | accuracy    0.570
# | epoch  18 |  4950/ 5775 batches | accuracy    0.549
# | epoch  18 |  5000/ 5775 batches | accuracy    0.556
# | epoch  18 |  5050/ 5775 batches | accuracy    0.554
# | epoch  18 |  5100/ 5775 batches | accuracy    0.559
# | epoch  18 |  5150/ 5775 batches | accuracy    0.539
# | epoch  18 |  5200/ 5775 batches | accuracy    0.546
# | epoch  18 |  5250/ 5775 batches | accuracy    0.545
# | epoch  18 |  5300/ 5775 batches | accuracy    0.553
# | epoch  18 |  5350/ 5775 batches | accuracy    0.548
# | epoch  18 |  5400/ 5775 batches | accuracy    0.542
# | epoch  18 |  5450/ 5775 batches | accuracy    0.523
# | epoch  18 |  5500/ 5775 batches | accuracy    0.561
# | epoch  18 |  5550/ 5775 batches | accuracy    0.583
# | epoch  18 |  5600/ 5775 batches | accuracy    0.558
# | epoch  18 |  5650/ 5775 batches | accuracy    0.552
# | epoch  18 |  5700/ 5775 batches | accuracy    0.537
# | epoch  18 |  5750/ 5775 batches | accuracy    0.552
# -----------------------------------------------------------
# | end of epoch  18 | time: 20.70s | valid accuracy    0.187
# -----------------------------------------------------------
# | epoch  19 |    50/ 5775 batches | accuracy    0.552
# | epoch  19 |   100/ 5775 batches | accuracy    0.551
# | epoch  19 |   150/ 5775 batches | accuracy    0.559
# | epoch  19 |   200/ 5775 batches | accuracy    0.535
# | epoch  19 |   250/ 5775 batches | accuracy    0.575
# | epoch  19 |   300/ 5775 batches | accuracy    0.553
# | epoch  19 |   350/ 5775 batches | accuracy    0.552
# | epoch  19 |   400/ 5775 batches | accuracy    0.569
# | epoch  19 |   450/ 5775 batches | accuracy    0.541
# | epoch  19 |   500/ 5775 batches | accuracy    0.547
# | epoch  19 |   550/ 5775 batches | accuracy    0.547
# | epoch  19 |   600/ 5775 batches | accuracy    0.531
# | epoch  19 |   650/ 5775 batches | accuracy    0.550
# | epoch  19 |   700/ 5775 batches | accuracy    0.554
# | epoch  19 |   750/ 5775 batches | accuracy    0.554
# | epoch  19 |   800/ 5775 batches | accuracy    0.569
# | epoch  19 |   850/ 5775 batches | accuracy    0.535
# | epoch  19 |   900/ 5775 batches | accuracy    0.522
# | epoch  19 |   950/ 5775 batches | accuracy    0.544
# | epoch  19 |  1000/ 5775 batches | accuracy    0.569
# | epoch  19 |  1050/ 5775 batches | accuracy    0.531
# | epoch  19 |  1100/ 5775 batches | accuracy    0.546
# | epoch  19 |  1150/ 5775 batches | accuracy    0.536
# | epoch  19 |  1200/ 5775 batches | accuracy    0.538
# | epoch  19 |  1250/ 5775 batches | accuracy    0.529
# | epoch  19 |  1300/ 5775 batches | accuracy    0.568
# | epoch  19 |  1350/ 5775 batches | accuracy    0.541
# | epoch  19 |  1400/ 5775 batches | accuracy    0.553
# | epoch  19 |  1450/ 5775 batches | accuracy    0.522
# | epoch  19 |  1500/ 5775 batches | accuracy    0.519
# | epoch  19 |  1550/ 5775 batches | accuracy    0.541
# | epoch  19 |  1600/ 5775 batches | accuracy    0.578
# | epoch  19 |  1650/ 5775 batches | accuracy    0.557
# | epoch  19 |  1700/ 5775 batches | accuracy    0.546
# | epoch  19 |  1750/ 5775 batches | accuracy    0.558
# | epoch  19 |  1800/ 5775 batches | accuracy    0.541
# | epoch  19 |  1850/ 5775 batches | accuracy    0.549
# | epoch  19 |  1900/ 5775 batches | accuracy    0.562
# | epoch  19 |  1950/ 5775 batches | accuracy    0.546
# | epoch  19 |  2000/ 5775 batches | accuracy    0.534
# | epoch  19 |  2050/ 5775 batches | accuracy    0.559
# | epoch  19 |  2100/ 5775 batches | accuracy    0.545
# | epoch  19 |  2150/ 5775 batches | accuracy    0.539
# | epoch  19 |  2200/ 5775 batches | accuracy    0.552
# | epoch  19 |  2250/ 5775 batches | accuracy    0.541
# | epoch  19 |  2300/ 5775 batches | accuracy    0.566
# | epoch  19 |  2350/ 5775 batches | accuracy    0.556
# | epoch  19 |  2400/ 5775 batches | accuracy    0.546
# | epoch  19 |  2450/ 5775 batches | accuracy    0.551
# | epoch  19 |  2500/ 5775 batches | accuracy    0.542
# | epoch  19 |  2550/ 5775 batches | accuracy    0.534
# | epoch  19 |  2600/ 5775 batches | accuracy    0.545
# | epoch  19 |  2650/ 5775 batches | accuracy    0.542
# | epoch  19 |  2700/ 5775 batches | accuracy    0.544
# | epoch  19 |  2750/ 5775 batches | accuracy    0.544
# | epoch  19 |  2800/ 5775 batches | accuracy    0.580
# | epoch  19 |  2850/ 5775 batches | accuracy    0.545
# | epoch  19 |  2900/ 5775 batches | accuracy    0.552
# | epoch  19 |  2950/ 5775 batches | accuracy    0.566
# | epoch  19 |  3000/ 5775 batches | accuracy    0.524
# | epoch  19 |  3050/ 5775 batches | accuracy    0.524
# | epoch  19 |  3100/ 5775 batches | accuracy    0.563
# | epoch  19 |  3150/ 5775 batches | accuracy    0.554
# | epoch  19 |  3200/ 5775 batches | accuracy    0.551
# | epoch  19 |  3250/ 5775 batches | accuracy    0.537
# | epoch  19 |  3300/ 5775 batches | accuracy    0.552
# | epoch  19 |  3350/ 5775 batches | accuracy    0.554
# | epoch  19 |  3400/ 5775 batches | accuracy    0.566
# | epoch  19 |  3450/ 5775 batches | accuracy    0.551
# | epoch  19 |  3500/ 5775 batches | accuracy    0.554
# | epoch  19 |  3550/ 5775 batches | accuracy    0.544
# | epoch  19 |  3600/ 5775 batches | accuracy    0.529
# | epoch  19 |  3650/ 5775 batches | accuracy    0.547
# | epoch  19 |  3700/ 5775 batches | accuracy    0.566
# | epoch  19 |  3750/ 5775 batches | accuracy    0.544
# | epoch  19 |  3800/ 5775 batches | accuracy    0.569
# | epoch  19 |  3850/ 5775 batches | accuracy    0.543
# | epoch  19 |  3900/ 5775 batches | accuracy    0.540
# | epoch  19 |  3950/ 5775 batches | accuracy    0.540
# | epoch  19 |  4000/ 5775 batches | accuracy    0.551
# | epoch  19 |  4050/ 5775 batches | accuracy    0.544
# | epoch  19 |  4100/ 5775 batches | accuracy    0.563
# | epoch  19 |  4150/ 5775 batches | accuracy    0.540
# | epoch  19 |  4200/ 5775 batches | accuracy    0.534
# | epoch  19 |  4250/ 5775 batches | accuracy    0.539
# | epoch  19 |  4300/ 5775 batches | accuracy    0.547
# | epoch  19 |  4350/ 5775 batches | accuracy    0.561
# | epoch  19 |  4400/ 5775 batches | accuracy    0.546
# | epoch  19 |  4450/ 5775 batches | accuracy    0.552
# | epoch  19 |  4500/ 5775 batches | accuracy    0.533
# | epoch  19 |  4550/ 5775 batches | accuracy    0.526
# | epoch  19 |  4600/ 5775 batches | accuracy    0.551
# | epoch  19 |  4650/ 5775 batches | accuracy    0.541
# | epoch  19 |  4700/ 5775 batches | accuracy    0.547
# | epoch  19 |  4750/ 5775 batches | accuracy    0.554
# | epoch  19 |  4800/ 5775 batches | accuracy    0.569
# | epoch  19 |  4850/ 5775 batches | accuracy    0.559
# | epoch  19 |  4900/ 5775 batches | accuracy    0.546
# | epoch  19 |  4950/ 5775 batches | accuracy    0.536
# | epoch  19 |  5000/ 5775 batches | accuracy    0.541
# | epoch  19 |  5050/ 5775 batches | accuracy    0.556
# | epoch  19 |  5100/ 5775 batches | accuracy    0.551
# | epoch  19 |  5150/ 5775 batches | accuracy    0.554
# | epoch  19 |  5200/ 5775 batches | accuracy    0.545
# | epoch  19 |  5250/ 5775 batches | accuracy    0.540
# | epoch  19 |  5300/ 5775 batches | accuracy    0.564
# | epoch  19 |  5350/ 5775 batches | accuracy    0.547
# | epoch  19 |  5400/ 5775 batches | accuracy    0.554
# | epoch  19 |  5450/ 5775 batches | accuracy    0.554
# | epoch  19 |  5500/ 5775 batches | accuracy    0.517
# | epoch  19 |  5550/ 5775 batches | accuracy    0.539
# | epoch  19 |  5600/ 5775 batches | accuracy    0.516
# | epoch  19 |  5650/ 5775 batches | accuracy    0.544
# | epoch  19 |  5700/ 5775 batches | accuracy    0.541
# | epoch  19 |  5750/ 5775 batches | accuracy    0.549
# -----------------------------------------------------------
# | end of epoch  19 | time: 20.81s | valid accuracy    0.187
# -----------------------------------------------------------
# | epoch  20 |    50/ 5775 batches | accuracy    0.561
# | epoch  20 |   100/ 5775 batches | accuracy    0.544
# | epoch  20 |   150/ 5775 batches | accuracy    0.554
# | epoch  20 |   200/ 5775 batches | accuracy    0.539
# | epoch  20 |   250/ 5775 batches | accuracy    0.542
# | epoch  20 |   300/ 5775 batches | accuracy    0.546
# | epoch  20 |   350/ 5775 batches | accuracy    0.542
# | epoch  20 |   400/ 5775 batches | accuracy    0.537
# | epoch  20 |   450/ 5775 batches | accuracy    0.547
# | epoch  20 |   500/ 5775 batches | accuracy    0.550
# | epoch  20 |   550/ 5775 batches | accuracy    0.568
# | epoch  20 |   600/ 5775 batches | accuracy    0.562
# | epoch  20 |   650/ 5775 batches | accuracy    0.540
# | epoch  20 |   700/ 5775 batches | accuracy    0.532
# | epoch  20 |   750/ 5775 batches | accuracy    0.541
# | epoch  20 |   800/ 5775 batches | accuracy    0.556
# | epoch  20 |   850/ 5775 batches | accuracy    0.540
# | epoch  20 |   900/ 5775 batches | accuracy    0.552
# | epoch  20 |   950/ 5775 batches | accuracy    0.551
# | epoch  20 |  1000/ 5775 batches | accuracy    0.574
# | epoch  20 |  1050/ 5775 batches | accuracy    0.541
# | epoch  20 |  1100/ 5775 batches | accuracy    0.549
# | epoch  20 |  1150/ 5775 batches | accuracy    0.551
# | epoch  20 |  1200/ 5775 batches | accuracy    0.547
# | epoch  20 |  1250/ 5775 batches | accuracy    0.542
# | epoch  20 |  1300/ 5775 batches | accuracy    0.549
# | epoch  20 |  1350/ 5775 batches | accuracy    0.539
# | epoch  20 |  1400/ 5775 batches | accuracy    0.545
# | epoch  20 |  1450/ 5775 batches | accuracy    0.540
# | epoch  20 |  1500/ 5775 batches | accuracy    0.527
# | epoch  20 |  1550/ 5775 batches | accuracy    0.558
# | epoch  20 |  1600/ 5775 batches | accuracy    0.545
# | epoch  20 |  1650/ 5775 batches | accuracy    0.538
# | epoch  20 |  1700/ 5775 batches | accuracy    0.536
# | epoch  20 |  1750/ 5775 batches | accuracy    0.547
# | epoch  20 |  1800/ 5775 batches | accuracy    0.529
# | epoch  20 |  1850/ 5775 batches | accuracy    0.542
# | epoch  20 |  1900/ 5775 batches | accuracy    0.544
# | epoch  20 |  1950/ 5775 batches | accuracy    0.545
# | epoch  20 |  2000/ 5775 batches | accuracy    0.556
# | epoch  20 |  2050/ 5775 batches | accuracy    0.538
# | epoch  20 |  2100/ 5775 batches | accuracy    0.526
# | epoch  20 |  2150/ 5775 batches | accuracy    0.568
# | epoch  20 |  2200/ 5775 batches | accuracy    0.534
# | epoch  20 |  2250/ 5775 batches | accuracy    0.551
# | epoch  20 |  2300/ 5775 batches | accuracy    0.541
# | epoch  20 |  2350/ 5775 batches | accuracy    0.536
# | epoch  20 |  2400/ 5775 batches | accuracy    0.550
# | epoch  20 |  2450/ 5775 batches | accuracy    0.546
# | epoch  20 |  2500/ 5775 batches | accuracy    0.527
# | epoch  20 |  2550/ 5775 batches | accuracy    0.554
# | epoch  20 |  2600/ 5775 batches | accuracy    0.550
# | epoch  20 |  2650/ 5775 batches | accuracy    0.536
# | epoch  20 |  2700/ 5775 batches | accuracy    0.554
# | epoch  20 |  2750/ 5775 batches | accuracy    0.533
# | epoch  20 |  2800/ 5775 batches | accuracy    0.558
# | epoch  20 |  2850/ 5775 batches | accuracy    0.547
# | epoch  20 |  2900/ 5775 batches | accuracy    0.526
# | epoch  20 |  2950/ 5775 batches | accuracy    0.540
# | epoch  20 |  3000/ 5775 batches | accuracy    0.552
# | epoch  20 |  3050/ 5775 batches | accuracy    0.554
# | epoch  20 |  3100/ 5775 batches | accuracy    0.552
# | epoch  20 |  3150/ 5775 batches | accuracy    0.539
# | epoch  20 |  3200/ 5775 batches | accuracy    0.539
# | epoch  20 |  3250/ 5775 batches | accuracy    0.553
# | epoch  20 |  3300/ 5775 batches | accuracy    0.556
# | epoch  20 |  3350/ 5775 batches | accuracy    0.544
# | epoch  20 |  3400/ 5775 batches | accuracy    0.527
# | epoch  20 |  3450/ 5775 batches | accuracy    0.548
# | epoch  20 |  3500/ 5775 batches | accuracy    0.532
# | epoch  20 |  3550/ 5775 batches | accuracy    0.553
# | epoch  20 |  3600/ 5775 batches | accuracy    0.541
# | epoch  20 |  3650/ 5775 batches | accuracy    0.566
# | epoch  20 |  3700/ 5775 batches | accuracy    0.571
# | epoch  20 |  3750/ 5775 batches | accuracy    0.562
# | epoch  20 |  3800/ 5775 batches | accuracy    0.536
# | epoch  20 |  3850/ 5775 batches | accuracy    0.552
# | epoch  20 |  3900/ 5775 batches | accuracy    0.549
# | epoch  20 |  3950/ 5775 batches | accuracy    0.558
# | epoch  20 |  4000/ 5775 batches | accuracy    0.568
# | epoch  20 |  4050/ 5775 batches | accuracy    0.547
# | epoch  20 |  4100/ 5775 batches | accuracy    0.541
# | epoch  20 |  4150/ 5775 batches | accuracy    0.546
# | epoch  20 |  4200/ 5775 batches | accuracy    0.564
# | epoch  20 |  4250/ 5775 batches | accuracy    0.566
# | epoch  20 |  4300/ 5775 batches | accuracy    0.569
# | epoch  20 |  4350/ 5775 batches | accuracy    0.527
# | epoch  20 |  4400/ 5775 batches | accuracy    0.573
# | epoch  20 |  4450/ 5775 batches | accuracy    0.551
# | epoch  20 |  4500/ 5775 batches | accuracy    0.567
# | epoch  20 |  4550/ 5775 batches | accuracy    0.550
# | epoch  20 |  4600/ 5775 batches | accuracy    0.544
# | epoch  20 |  4650/ 5775 batches | accuracy    0.560
# | epoch  20 |  4700/ 5775 batches | accuracy    0.552
# | epoch  20 |  4750/ 5775 batches | accuracy    0.549
# | epoch  20 |  4800/ 5775 batches | accuracy    0.529
# | epoch  20 |  4850/ 5775 batches | accuracy    0.545
# | epoch  20 |  4900/ 5775 batches | accuracy    0.550
# | epoch  20 |  4950/ 5775 batches | accuracy    0.532
# | epoch  20 |  5000/ 5775 batches | accuracy    0.546
# | epoch  20 |  5050/ 5775 batches | accuracy    0.554
# | epoch  20 |  5100/ 5775 batches | accuracy    0.534
# | epoch  20 |  5150/ 5775 batches | accuracy    0.548
# | epoch  20 |  5200/ 5775 batches | accuracy    0.573
# | epoch  20 |  5250/ 5775 batches | accuracy    0.529
# | epoch  20 |  5300/ 5775 batches | accuracy    0.548
# | epoch  20 |  5350/ 5775 batches | accuracy    0.541
# | epoch  20 |  5400/ 5775 batches | accuracy    0.548
# | epoch  20 |  5450/ 5775 batches | accuracy    0.535
# | epoch  20 |  5500/ 5775 batches | accuracy    0.543
# | epoch  20 |  5550/ 5775 batches | accuracy    0.567
# | epoch  20 |  5600/ 5775 batches | accuracy    0.532
# | epoch  20 |  5650/ 5775 batches | accuracy    0.572
# | epoch  20 |  5700/ 5775 batches | accuracy    0.564
# | epoch  20 |  5750/ 5775 batches | accuracy    0.556
# -----------------------------------------------------------
# | end of epoch  20 | time: 21.18s | valid accuracy    0.187
# -----------------------------------------------------------

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = TextClassificationModel(vocab_size=100124, embed_dim=64, num_class=9).to(device)
model.load_state_dict(torch.load("model.pth"))
model.eval()
train,test = return_iters("../../../data/9_labels/linear/full")
test_dataset = to_map_style_dataset(test)

test_dataloader = DataLoader(test_dataset, batch_size=32,
                                 shuffle=True, collate_fn=collate_batch)
test_accuracy= evaluate(test_dataloader,model)
print(test_accuracy)
# Out:
# 0.5294404943679277
